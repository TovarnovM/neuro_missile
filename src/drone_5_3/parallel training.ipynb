# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from drone_sac import AgentParallel3layers, BufferParallel
from drone_gym import DroneGym
from tqdm.notebook import tqdm
import torch as T
import matplotlib.pyplot as plt
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: easyvec.vectors.Vec3 size changed, may indicate binary incompatibility. Expected 40 from C header, got 48 from PyObject

# %%
from distributed import Client, LocalCluster

n_workers  = 20
cl = Client(LocalCluster(n_workers=n_workers, threads_per_worker=1))
cl
# Out:
# <Client: 'tcp://127.0.0.1:29079' processes=20 threads=20, memory=63.93 GiB>

# %%
def generate_data(agent_dict, n_points):
    try:
        import sys
        sys.path.append(r'D:\neuro_missile\src\cydrone')
        sys.path.append(r'D:\neuro_missile\src\drone_5_3')
        import numpy as np
        from drone_sac import AgentParallel3layers, BufferParallel
        from drone_gym import DroneGym
        
#         import pickle
#         with open('agent_dict.bin', 'rb') as f:
#             agent_dict = pickle.load(f)
        
        env = DroneGym.make()
        agent = AgentParallel3layers(
            input_dims=env.obs_max.shape, 
            n_actions=2, 
            action_space_high=env.action_space.high,
            device_name='cpu')
        agent.from_dict(agent_dict)
        buffer = BufferParallel(agent)

        env.record_history = False
        env.antiflip = False
        n = 0
        while n < n_points:
            observation = env.reset()
            done = False
            while not done:
                action = agent.choose_action(observation)
#                 action = np.random.uniform(0.97,1, size=2)
                observation_, reward, done, info = env.step(action)
                buffer.store_transition(observation, action, reward, observation_, done)
                observation = observation_
                n += 1
                if n >= n_points*5:
                    return True, buffer.to_dict(), info
        return True, buffer.to_dict(), info
    except Exception as e:
        return False, {'error': str(e)}

# %%
env = DroneGym.make()
agent = AgentParallel3layers(input_dims=env.obs_max.shape, n_actions=2, action_space_high=env.action_space.high)
buffer = BufferParallel(agent)

# import pickle
# with open('agent_dict.bin', 'rb') as f:
#     agent_dict = pickle.load(f)
# agent.from_dict(agent_dict)

# %%
def run_parallel_sim(n):
    d = agent.to_dict()
    dicts_futs = cl.scatter([d] * n_workers)
    n_pointss = [n] * n_workers
    futs = cl.map(generate_data, dicts_futs, n_pointss, pure=False)
    return futs 

def run_parallel_sim_file(n):
    import pickle
    with open('agent_dict.bin', 'wb') as f:
        pickle.dump(agent.to_dict(), f)
    n_pointss = [n] * n_workers
    futs = cl.map(generate_data_file, n_pointss, pure=False)
    return futs 

def extend_buff(futs):
    results = cl.gather(futs)
    for suc, points, info in results:
        infos.append(info)
        if suc:
            buffer.extend_from_dict(points)
            
def learn(batch_size, refresh=True):
    if refresh:
        buffer.refresh()
    losses = []
    for batch in buffer.iter_batches(batch_size):
        losses.append(agent.learn(*batch))
    return np.mean(losses, axis=0)

def plot_losses(ax_value, ax_actor, ax_critic, losses):
    ax_value.plot([val for val, act, crit in losses])
    ax_actor.plot([act for val, act, crit in losses])
    ax_critic.plot([crit for val, act, crit in losses])
    
    ax_value.grid()
    ax_actor.grid()
    ax_critic.grid()

# %%
infos = []

# %%
buffer = BufferParallel(agent)

# %%
futs = run_parallel_sim(10000)
extend_buff(futs)
learn(256)
# Out:
# array([  14.101741,  -16.183157, 1535.5999  ], dtype=float32)

# %%
losses = []

# %%
import pickle
for i in tqdm(range(30000)):
    futs = run_parallel_sim(3000)
    buffer.refresh()
    first = True
    while not all([f.status in {'finished', 'error'} for f in futs]) or first:
        first = False
        alpha,beta=np.random.uniform(0.00001, 0.0003, size=2)
        agent.change_lr(alpha=alpha, beta=beta)
        losses.append(learn(1024*4, False))
    extend_buff(futs)   
    buffer.trim_oldest(2000000, False)
    with open('agent_dict2.bin', 'wb') as f:
        pickle.dump(agent.to_dict(), f)
buffer.refresh()
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1cc104977385> in <module>
#       8         alpha,beta=np.random.uniform(0.00001, 0.0003, size=2)
#       9         agent.change_lr(alpha=alpha, beta=beta)
# ---> 10         losses.append(learn(1024*4, False))
#      11     extend_buff(futs)
#      12     buffer.trim_oldest(2000000, False)
#
# <ipython-input-6-516cf534913e> in learn(batch_size, refresh)
#      26     losses = []
#      27     for batch in buffer.iter_batches(batch_size):
# ---> 28         losses.append(agent.learn(*batch))
#      29     return np.mean(losses, axis=0)
#      30
#
# D:\neuro_missile\src\drone_5_3\drone_sac.py in learn(self, state, action, reward, new_state, done)
#     136
#     137         critic_loss = critic_1_loss + critic_2_loss
# --> 138         critic_loss.backward()
#     139         self.critic_1.optimizer.step()
#     140         self.critic_2.optimizer.step()
#
# D:\neuro_missile\env_neuro_missile\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# D:\neuro_missile\env_neuro_missile\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
alpha=np.random.uniform(0.00001, 0.0003)
agent.change_lr(alpha=alpha, beta=alpha)

# %%
buffer.refresh()
# Out:
# 1500000

# %%
for i in tqdm(range(30)):
    losses.append(learn(512, False))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-450e59b5e282> in <module>
#       1 for i in tqdm(range(30)):
# ----> 2     losses.append(learn(512, False))
#
# <ipython-input-6-516cf534913e> in learn(batch_size, refresh)
#      26     losses = []
#      27     for batch in buffer.iter_batches(batch_size):
# ---> 28         losses.append(agent.learn(*batch))
#      29     return np.mean(losses, axis=0)
#      30
#
# D:\neuro_missile\src\drone_1_3\drone_sac.py in learn(self, state, action, reward, new_state, done)
#     117         log_probs = log_probs.view(-1)
#     118         q1_new_policy = self.critic_1.forward(state, actions)
# --> 119         q2_new_policy = self.critic_2.forward(state, actions)
#     120         critic_value = T.min(q1_new_policy, q2_new_policy)
#     121         critic_value = critic_value.view(-1)
#
# D:\neuro_missile\src\drone_1_3\sac_networks3layers.py in forward(self, state, action)
#      34
#      35     def forward(self, state, action):
# ---> 36         action_value = self.fc1(T.cat([state, action], dim=1))
#      37         action_value = F.relu(action_value)
#      38         action_value = self.fc2(action_value)
#
# KeyboardInterrupt:

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(9,9))
plot_losses(ax1, ax2, ax3, losses[:])
plt.show()

# %%
successes = [i for i in infos if 'result' in i and i['result'] == 'success']
len(successes)/len(infos)
# Out:
# 0.7011795543905636

# %%
[i for i in infos if 'result' in i and i['result'] != 'success']
# Out:
# [{'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch -23.010031735460537'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch -23.038038299344528'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch -23.019260558308467'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch -23.00478012832574'},
#  {'result': 'omega too mutch -23.019843646869262'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch -23.019292532543403'},
#  {'result': 'omega too mutch -23.012250853653242'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of X bounds'},
#  {'result': 'out of X bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of X bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch 23.022568578020568'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch 23.008214062467477'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch 23.03168032064594'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch 23.00820637031435'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'omega too mutch 23.041736185930446'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  {'result': 'out of Y bounds'},
#  ...]

# %%
final_rewards = [i['final_reward'] for i in successes]
max(final_rewards), min(final_rewards), np.mean(final_rewards)
# Out:
# (22.150455800597452, -12.843475206819512, 10.17548901137921)

# %%
import pickle
# with open('agent_dict.bin', 'rb') as f:
#     agent_dict = pickle.load(f)
# agent.from_dict(agent_dict)

with open('agent_dict.bin', 'wb') as f:
    pickle.dump(agent.to_dict(), f)

# %%
env = DroneGym.make()

# %%
score = 0
env.record_history = True
env.antiflip = False
for i in tqdm(range(1)):
    observation = env.reset()
    done = False
    score = 0
    while not done:
        action = np.random.uniform(0.6,1, size=2)
        action[1] = np.random.uniform(-0.5,0.5)
        action = agent.choose_action_determ(observation)
#         action[0] *= 2
        observation_, reward, done, info = env.step(action)
        score += reward
        buffer.store_transition(observation, action, reward, observation_, done)
        observation = observation_
#     buffer.refresh()
#     for batch in buffer.iter_batches(2048):
#         agent.learn(*batch)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
info
# Out:
# {'result': 'out of Y bounds'}

# %%
buffer.refresh()
# Out:
# 2003869

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets
import matplotlib.pyplot as plt
gym = env

xs = []
ys = []
f1s = []
f2s = []
rewards = []
ts = []
dts = []
scores = [0]
vels = []
for d in gym.history:
    gym.set_state(d['state'])
    xs.append(gym.drone.pos.x)
    ys.append(gym.drone.pos.y)
    f1, f2 = d['actions']
    f1s.append(f1)
    f2s.append(f2)
    ts.append(gym.time_curr)
    rewards.append(d['reward'])
    dts.append(d['delta_t1'])
    scores.append(scores[-1]+d['reward'])
    vels.append(gym.drone.vel.len())
scores = scores[1:]
i1=0
i2=-1
# plt.plot(ts[i1:i2], rewards[i1:i2])
plt.plot(ts[i1:i2], f1s[i1:i2])
plt.plot(ts[i1:i2], f2s[i1:i2])
# plt.plot(ts[i1:i2], dts[i1:i2])

# %%
@interact(i=ipywidgets.IntSlider(min=0,max=len(gym.history)-1,step=1, value=0))
def plot_history(i):
    d = gym.history[i]
    i1=max(0,i-30)
    i2=i+1
    gym.set_state(d['state'])
    fig, (ax, ax2, ax3) = plt.subplots(1,3, figsize=(14,7))
    gym.plot(ax, drone_mashtb=20, vec_mashtb=1, actions=d['actions'],ideal_traj=True)
    ax.plot(xs[i1:i],ys[i1:i],ls=':')
    ax.set_aspect('equal', adjustable='box')
    
    
#     ax2.plot(ts[i1:i2], f1s[i1:i2])
#     ax2.plot(ts[i1:i2], f2s[i1:i2])
    ax2.grid()
    ax2.plot(ts[:i2], vels[:i2])
    
    ax3.plot(ts[i1:i2], rewards[i1:i2])
    ax3.grid()
    ax.grid()
    plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=857), Output()), _dom_classes=('widget-interact'…

# %%
info
# Out:
# {'result': 'out of Y bounds'}

# %%
gym.vel_trg
# Out:
# Vec2(3.718528711513613, 6.331224598978329)
